# %% [markdown]
# # Calculating The Value of Pi

# %% [markdown]
# I followed the classical approach to calculate the value of Pi ie. by dividing the Circumference of circle with its diameter<br>A geometry compass, a cotton thread and a meter scale are all that I needed<img src="Pi/1.jpg",width=400,height=300><br> Drew a circle on paper of a random radius and <br>After neaty covering the circumference with the thread <br> <img src="Pi/3.jpg",width=400,height=300> <br> Retrieved the thread that now holds the value of the circumference <img src="Pi/4.jpg",width=400,height=300> <br> Now all that was left was <br><strong>Measurements</strong><br>Diameter = 15.79<br>Circumference = 49.7

# %% [markdown]
# # Check for Irrationality

# %% [markdown]
# Pi is one of the greatest Irrational numbers ever discovered by humans. It can't be expressed in p/q form and the digits are nonrepeating till infinity <br>

# %%
from decimal import *

# %% [markdown]
# Lets set the precision at 100000

# %%
getcontext().prec = 100000

# %%
Decimal(49.7) / Decimal(15.79)
# Out:
# Decimal('3....')
